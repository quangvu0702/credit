# %%
# %load_ext autoreload
# %autoreload 2

# %%
import random
import pandas as pd
import numpy as np


def shuffle_dataset(n, s=30, ratial=80):
    start_valid = int((n / 100) * ratial)
    random.seed(s)
    xs = list(range(n))
    random.seed(30)
    random.shuffle(xs)
    return xs[:start_valid], xs[start_valid:]

def load_data(is_train=True):
    random.seed(30)
    X = pd.read_csv('data/train.csv')
    train_ids, valid_ids = shuffle_dataset(len(X))
    Y = X[['label']]
    del X['label']
    train_X, train_Y = X.iloc[train_ids], Y.iloc[train_ids]
    valid_X, valid_Y = X.iloc[valid_ids], Y.iloc[valid_ids]
    return train_X, train_Y, valid_X, valid_Y

# %%
train_X, train_Y, valid_X, valid_Y = load_data()
len(train_X), len(train_Y), len(valid_X), len(valid_Y)
# Out:
# /home/vule/miniconda3/envs/thanos/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# (24000, 24000, 6000, 6000)

# %%
train_X.sample(3)
# Out:
#           id      province         district  age_source1  age_source2  \
# 29004  29004  Tỉnh Nghệ An    Huyện Nam Đàn         28.0         28.0
# 14839  14839  Tỉnh Nghệ An  Huyện Yên Thành         23.0         23.0
# 11920  11920           NaN              NaN          NaN          NaN
#
#                           maCv  FIELD_1  FIELD_2  FIELD_3  FIELD_4  ...  \
# 29004  Công nhân sản xuất VLXD        1      1.0   3646.0      0.0  ...
# 14839               Kỹ sư Điện        0      1.0   1068.0      3.0  ...
# 11920                      NaN        1      0.0     -1.0      0.0  ...
#
#        FIELD_48  FIELD_49 FIELD_50 FIELD_51 FIELD_52 FIELD_53 FIELD_54  \
# 29004      True      True    29.77   54.129   30.955   31.171      0.0
# 14839      True      True    29.77   62.211   30.955   31.171      0.0
# 11920     False      True      NaN      NaN      NaN      NaN      NaN
#
#       FIELD_55 FIELD_56  FIELD_57
# 29004     0.15      0.0       0.0
# 14839     0.20      0.0       0.0
# 11920      NaN      NaN       NaN
#
# [3 rows x 63 columns]

# %% [markdown]
# ### Do some stats

# %%
from collections import Counter

def stats(df):
    xs = df[df.notna()]
    c = df.columns[0]
    print(f"min: {xs.min()[c]}, max: {xs.max()[c]}, mean {xs.mean()[c]}, median {xs.median()[c]}, std {xs.std()[c]}")
    
def stats_df(df):
    for c in df.columns:
        stats = Counter(df[c])
        print(f"{c}: {len(stats)} elements, tops 4: {stats.most_common(4)}")

# %%
train_X
# Out:
#           id               province        district  age_source1  age_source2  \
# 25383  25383                    NaN             NaN          NaN          NaN
# 7308    7308                    NaN             NaN          NaN         23.0
# 6149    6149                    NaN             NaN          NaN         53.0
# 2220    2220                    NaN             NaN          NaN         28.0
# 14015  14015                    NaN             NaN          NaN          NaN
# ...      ...                    ...             ...          ...          ...
# 27199  27199  Thành phố Hồ Chí Minh    Quận Thủ Đức         28.0         28.0
# 4790    4790         Tỉnh Thanh Hóa  Huyện Hà Trung         30.0         30.0
# 29755  29755                    NaN             NaN          NaN          NaN
# 28254  28254                    NaN             NaN          NaN         21.0
# 10173  10173    Thành phố Hải Phòng  Quận Ngô Quyền         50.0         50.0
#
#             maCv  FIELD_1  FIELD_2  FIELD_3  FIELD_4  ...  FIELD_48  FIELD_49  \
# 25383        NaN        0      0.0     -1.0      0.0  ...     False      True
# 7308        None        1      1.0   1073.0      0.0  ...      True      True
# 6149        None        1      0.0     -1.0      0.0  ...     False      True
# 2220   nhân viên        1      1.0   1080.0      0.0  ...     False      True
# 14015        NaN        1      1.0    363.0      0.0  ...      True      True
# ...          ...      ...      ...      ...      ...  ...       ...       ...
# 27199  Nhân viên        1      1.0   2900.0      1.0  ...      True      True
# 4790        None        1      1.0   2191.0      0.0  ...      True     False
# 29755        NaN        1      1.0   3994.0      0.0  ...      True      True
# 28254       None        0      0.0     -1.0      0.0  ...     False      True
# 10173       None        1      0.0     -1.0      3.0  ...     False      True
#
#       FIELD_50 FIELD_51 FIELD_52 FIELD_53 FIELD_54 FIELD_55 FIELD_56  FIELD_57
# 25383      NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 7308     29.77   44.098   30.955   31.171      0.0     0.14     0.00      0.00
# 6149     29.77   11.102   30.955   31.171      0.0     0.03     0.00      0.00
# 2220     29.77   45.303   30.955   31.171      0.0     0.14     0.00      0.00
# 14015      NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# ...        ...      ...      ...      ...      ...      ...      ...       ...
# 27199    29.77   66.268   30.955   31.171      0.0     0.30     0.00      0.00
# 4790     29.77   31.170   30.955   31.171      0.0     0.10     0.00      0.00
# 29755      NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 28254    29.77   17.561   63.607   63.591      0.0     0.04     0.05      0.05
# 10173    29.77   21.478   30.955   31.171      0.0     0.05     0.00      0.00
#
# [24000 rows x 63 columns]

# %%
# stats_df(train_X)

# %%
class DataBunch():
    def __init__(self, train_X, train_Y, valid_X, valid_Y):
        self.train_X, self.train_Y, self.valid_X, self.valid_Y = train_X, train_Y, valid_X, valid_Y
        self.assets = {}
        self.train_X = self.filling_na(self.train_X)
    def add_asset(self, k,v):
        self.assets[k] = v

    def filling_na(self, df):
        df = self._preprocess_FIELD_3(df)
        df = self._preprocess_FIELD_7(df)
        fillan_unknown_list = ['province', 'district', 'maCv', 'FIELD_1', 'FIELD_2', 'FIELD_4',
                               'FIELD_5', 'FIELD_6', 'FIELD_8', 'FIELD_9',
                               'FIELD_10', 'FIELD_11', 'FIELD_12', 'FIELD_13', 'FIELD_14', 'FIELD_15',
                              'FIELD_16', 'FIELD_17', 'FIELD_18', 'FIELD_19', 'FIELD_20', 'FIELD_21',
                              'FIELD_23', 'FIELD_24', 'FIELD_25', 'FIELD_26', 'FIELD_27', 'FIELD_28',
                              'FIELD_29', 'FIELD_30', 'FIELD_31', 'FIELD_32', 'FIELD_33', 'FIELD_34',
                              'FIELD_35', 'FIELD_36', 'FIELD_37', 'FIELD_38', 'FIELD_39', 'FIELD_40', 'FIELD_41',
                              'FIELD_42', 'FIELD_43', 'FIELD_44', 'FIELD_45', 'FIELD_46', 'FIELD_47',
                               'FIELD_48', 'FIELD_49', 'FIELD_50']
        fillan_median_list = ['age_source1', 'age_source2',
                              'FIELD_22', 'FIELD_51', 'FIELD_52', 'FIELD_53', 'FIELD_54', 'FIELD_55', 'FIELD_56', 'FIELD_57']
        df = self._fillna_unknown(df, fillan_unknown_list)
        df = self._fillna_median(df, fillan_median_list)
        return df
    
    def _fillna_median(self, df, columns):
        for c in columns:
            if c not in self.assets:
                median = df[[c]].median()[c]
                self.add_asset(c, median)
            df[[c]] = df[[c]].fillna(self.assets[c])
            stats(df[[c]])
        return df
    
    def _fillna_unknown(self, df, columns):
        for c in columns:
            if c not in self.assets:
                self.add_asset(c, 'unknown')
            df[[c]] = df[[c]].fillna(self.assets[c])
            stats_df(df[[c]])
        return df
    
    def _preprocess_FIELD_3(self, df, mode='-1'):
        c = 'FIELD_3'
        if c not in self.assets:
            if mode == '-1':
                self.add_asset(c, -1)

        df[[c]] = df[[c]].fillna(self.assets[c])
        stats(df[[c]])
        return df
    
    def _preprocess_FIELD_7(self, df):
        c = 'FIELD_7'
        if c not in self.assets:
            self.add_asset(c, [])
        df[[c]] = df[[c]].fillna(0)
        df[c] = df[c].apply(lambda x: x if x else [])
        return df

# %%
train_X.columns
# Out:
# Index(['id', 'province', 'district', 'age_source1', 'age_source2', 'maCv',
#        'FIELD_1', 'FIELD_2', 'FIELD_3', 'FIELD_4', 'FIELD_5', 'FIELD_6',
#        'FIELD_7', 'FIELD_8', 'FIELD_9', 'FIELD_10', 'FIELD_11', 'FIELD_12',
#        'FIELD_13', 'FIELD_14', 'FIELD_15', 'FIELD_16', 'FIELD_17', 'FIELD_18',
#        'FIELD_19', 'FIELD_20', 'FIELD_21', 'FIELD_22', 'FIELD_23', 'FIELD_24',
#        'FIELD_25', 'FIELD_26', 'FIELD_27', 'FIELD_28', 'FIELD_29', 'FIELD_30',
#        'FIELD_31', 'FIELD_32', 'FIELD_33', 'FIELD_34', 'FIELD_35', 'FIELD_36',
#        'FIELD_37', 'FIELD_38', 'FIELD_39', 'FIELD_40', 'FIELD_41', 'FIELD_42',
#        'FIELD_43', 'FIELD_44', 'FIELD_45', 'FIELD_46', 'FIELD_47', 'FIELD_48',
#        'FIELD_49', 'FIELD_50', 'FIELD_51', 'FIELD_52', 'FIELD_53', 'FIELD_54',
#        'FIELD_55', 'FIELD_56', 'FIELD_57'],
#       dtype='object')

# %%
db = DataBunch(*load_data())
# Out:
# /home/vule/miniconda3/envs/thanos/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# min: -1.0, max: 8037.0, mean 1696.04775, median 1446.0, std 1473.9720286924098
# province: 66 elements, tops 4: [('unknown', 10320), ('Thành phố Hồ Chí Minh', 1887), ('Tỉnh Đồng Nai', 797), ('Tỉnh Bình Dương', 637)]
# district: 702 elements, tops 4: [('unknown', 10343), ('Huyện Châu Thành', 339), ('Thành phố Biên Hòa', 247), ('Thị xã Thuận An', 187)]
# maCv: 2547 elements, tops 4: [('None', 10532), ('unknown', 7763), ('Công nhân', 612), ('công nhân', 364)]
# FIELD_1: 2 elements, tops 4: [(1, 18601), (0, 5399)]
# FIELD_2: 3 elements, tops 4: [(1.0, 18030), (0.0, 5589), ('unknown', 381)]
# FIELD_4: 11 elements, tops 4: [(0.0, 15810), (1.0, 3821), (2.0, 2796), (3.0, 823)]
# FIELD_5: 16 elements, tops 4: [(0.0, 9937), (2.0, 3722), (3.0, 2685), (1.0, 2449)]
# FIELD_6: 6 elements, tops 4: [(0.0, 21136), (1.0, 1701), (2.0, 719), ('unknown', 381)]
# FIELD_8: 3 elements, tops 4: [('MALE', 8777), ('unknown', 7762), ('FEMALE', 7461)]
# FIELD_9: 35 elements, tops 4: [('DN', 8803), ('na', 7762), ('GD', 3875), ('TN', 839)]
# FIELD_10: 3 elements, tops 4: [('T1', 8665), ('unknown', 7762), ('GH', 7573)]
# FIELD_11: 42 elements, tops 4: [('unknown', 7762), ('12', 6818), ('0', 4411), ('6', 1683)]
# FIELD_12: 6 elements, tops 4: [('0', 13275), ('unknown', 7762), ('None', 2900), ('1', 61)]
# FIELD_13: 210 elements, tops 4: [('unknown', 7784), ('YN', 3970), ('BI', 3876), ('TA', 959)]
# FIELD_14: 2 elements, tops 4: [(0, 14423), (1, 9577)]
# FIELD_15: 2 elements, tops 4: [(0, 14489), (1, 9511)]
# FIELD_16: 6 elements, tops 4: [(1.0, 14721), ('unknown', 7762), (2.0, 1357), (3.0, 135)]
# FIELD_17: 9 elements, tops 4: [('None', 13250), ('unknown', 7762), ('G8', 2866), ('G3', 62)]
# FIELD_18: 3 elements, tops 4: [(True, 9210), ('unknown', 7762), (False, 7028)]
# FIELD_19: 3 elements, tops 4: [(False, 12207), ('unknown', 7762), (True, 4031)]
# FIELD_20: 3 elements, tops 4: [(False, 13707), ('unknown', 7762), (True, 2531)]
# FIELD_21: 4 elements, tops 4: [(1.0, 16217), ('unknown', 7762), (2.0, 13), (0.0, 8)]
# FIELD_23: 2 elements, tops 4: [(True, 16238), ('unknown', 7762)]
# FIELD_24: 5 elements, tops 4: [('None', 15837), ('unknown', 7762), ('K2', 178), ('K1', 133)]
# FIELD_25: 3 elements, tops 4: [(True, 12656), ('unknown', 7762), (False, 3582)]
# FIELD_26: 3 elements, tops 4: [(False, 9817), ('unknown', 7762), (True, 6421)]
# FIELD_27: 3 elements, tops 4: [(True, 16083), ('unknown', 7762), (False, 155)]
# FIELD_28: 3 elements, tops 4: [(True, 16082), ('unknown', 7762), (False, 156)]
# FIELD_29: 4 elements, tops 4: [('FALSE', 13332), ('unknown', 7762), ('None', 2905), ('TRUE', 1)]
# FIELD_30: 4 elements, tops 4: [('FALSE', 8405), ('unknown', 7762), ('TRUE', 4506), ('None', 3327)]
# FIELD_31: 3 elements, tops 4: [('FALSE', 12821), ('unknown', 7762), ('None', 3417)]
# FIELD_32: 2 elements, tops 4: [(0, 15879), (1, 8121)]
# FIELD_33: 2 elements, tops 4: [(1, 16410), (0, 7590)]
# FIELD_34: 2 elements, tops 4: [(0, 13046), (1, 10954)]
# FIELD_35: 6 elements, tops 4: [('unknown', 7762), ('Zero', 7338), ('One', 3595), ('Four', 3238)]
# FIELD_36: 4 elements, tops 4: [('FALSE', 12698), ('unknown', 7762), ('TRUE', 3535), ('None', 5)]
# FIELD_37: 6 elements, tops 4: [(True, 8343), ('unknown', 7762), ('TRUE', 6893), (False, 552)]
# FIELD_38: 3 elements, tops 4: [(False, 16138), ('unknown', 7762), (True, 100)]
# FIELD_39: 45 elements, tops 4: [('VN', 8466), ('unknown', 7762), ('None', 7164), ('TW', 129)]
# FIELD_40: 10 elements, tops 4: [('None', 12203), ('unknown', 7762), ('1', 3919), ('02 05 08 11', 57)]
# FIELD_41: 6 elements, tops 4: [('I', 10343), ('unknown', 7762), ('V', 3878), ('II', 897)]
# FIELD_42: 3 elements, tops 4: [('Zezo', 16116), ('unknown', 7762), ('One', 122)]
# FIELD_43: 7 elements, tops 4: [('None', 15288), ('unknown', 7762), ('C', 512), ('B', 294)]
# FIELD_44: 4 elements, tops 4: [('One', 11898), ('unknown', 7762), ('Two', 4312), ('None', 28)]
# FIELD_45: 6 elements, tops 4: [('1', 10413), ('unknown', 7762), ('2', 2874), (1.0, 2334)]
# FIELD_46: 2 elements, tops 4: [(0, 14375), (1, 9625)]
# FIELD_47: 2 elements, tops 4: [(True, 14035), (False, 9965)]
# FIELD_48: 2 elements, tops 4: [(True, 16639), (False, 7361)]
# FIELD_49: 2 elements, tops 4: [(True, 21075), (False, 2925)]
# FIELD_50: 10 elements, tops 4: [(29.77, 14252), ('unknown', 7762), (60.946000000000005, 675), (63.293, 467)]
# min: 0.0, max: 71.0, mean 32.17033333333333, median 31.0, std 6.99402898244422
# min: 6.0, max: 89.0, mean 32.267, median 31.0, std 7.524160188427086
# min: 0.0, max: 433.0, mean 35.2565, median 23.0, std 47.055923841556734
# min: 4.413, max: 67.633, mean 33.63417983333272, median 33.567499999999995, std 16.081300372324876
# min: 30.955, max: 67.634, mean 32.908882083323284, median 30.955, std 7.902256294697767
# min: 31.171, max: 67.634, mean 32.97132308331683, median 31.171, std 7.60244243231552
# min: 0.0, max: 1.0, mean 0.02508833333333339, median 0.0, std 0.0980677550680178
# min: 0.0, max: 1.0, mean 0.10546166666666693, median 0.11, std 0.07062496979931046
# min: 0.0, max: 0.92, mean 0.005785416666666642, median 0.0, std 0.026899750999809253
# min: 0.0, max: 0.92, mean 0.005586666666666646, median 0.0, std 0.026846524037246484

# %%
assert set(db.train_X.columns) - set(db.assets.keys()) == {'id'}
